# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import dash_core_components
import plotly.figure_factory as ff
import plotly.graph_objs as go
from plotly.offline import *

# %%
df = pd.read_excel("Data_Cortex_Nuclear.xls")
df.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N  \
# 0   309_1  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830
# 1   309_2  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636
# 2   309_3  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011
# 3   309_4  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886
# 4   309_5  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106
#
#     pBRAF_N  pCAMKII_N   pCREB_N  ...   pCFOS_N     SYP_N  H3AcK18_N  \
# 0  0.177565   2.373744  0.232224  ...  0.108336  0.427099   0.114783
# 1  0.172817   2.292150  0.226972  ...  0.104315  0.441581   0.111974
# 2  0.175722   2.283337  0.230247  ...  0.106219  0.435777   0.111883
# 3  0.176463   2.152301  0.207004  ...  0.111262  0.391691   0.130405
# 4  0.173627   2.134014  0.192158  ...  0.110694  0.434154   0.118481
#
#      EGR1_N  H3MeK4_N    CaNA_N  Genotype  Treatment  Behavior   class
# ...

# %%
df = df[["pPKCG_N", "pP70S6_N", "pS6_N", "pGSK3B_N", "ARC_N","class"]]
df.head()
# Out:
#     pPKCG_N  pP70S6_N     pS6_N  pGSK3B_N     ARC_N   class
# 0  1.443091  0.294170  0.106305  0.192608  0.106305  c-CS-m
# 1  1.439460  0.276431  0.106592  0.194815  0.106592  c-CS-m
# 2  1.524364  0.256648  0.108303  0.200737  0.108303  c-CS-m
# 3  1.612382  0.398534  0.103184  0.184169  0.103184  c-CS-m
# 4  1.645807  0.393447  0.104784  0.185718  0.104784  c-CS-m

# %%
df = df[(df["class"] == 't-CS-s') | (df["class"] == 'c-CS-s')]

# %%
fig = ff.create_scatterplotmatrix(df, diag='histogram', index='class', height=1000, width=1000)

iplot(fig)
# Out:
# <div>
#
#
#             <div id="077566cb-b468-4909-9d4a-1dad22b9a5fa" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("077566cb-b468-4909-9d4a-1dad22b9a5fa")) {
#                     Plotly.newPlot(
#                         '077566cb-b468-4909-9d4a-1dad22b9a5fa',
# ...

# %%
fig = px.scatter_matrix(df, 
                        dimensions=["pPKCG_N", "pP70S6_N", "pS6_N", "pGSK3B_N", "ARC_N"], 
                        color="class", width=1000, height=1000)

fig.show()
# Out:
# <div>
#
#
#             <div id="3e4bcb59-d376-4518-a131-cfc119faf2a2" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3e4bcb59-d376-4518-a131-cfc119faf2a2")) {
#                     Plotly.newPlot(
#                         '3e4bcb59-d376-4518-a131-cfc119faf2a2',
# ...
